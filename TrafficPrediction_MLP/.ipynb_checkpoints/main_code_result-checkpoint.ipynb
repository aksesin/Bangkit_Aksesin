# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import keras
import math
from keras.models import Sequential
from keras.layers import Dense
# %matplotlib inline

# %%
df = pd.read_csv('input/traffic/DataSet/datatrain27303.csv')
df.head()
# Out:
#              timestamp  hourly_traffic_count  green_light
# 0  2015-10-04 00:00:00                     3           15
# 1  2015-10-04 00:05:00                    16           25
# 2  2015-10-04 00:10:00                     9           15
# 3  2015-10-04 00:15:00                    12           25
# 4  2015-10-04 00:20:00                    19           25

# %%
df1 = df.reset_index()['hourly_traffic_count']
df1.head()
# Out:
# 0     3
# 1    16
# 2     9
# 3    12
# 4    19
# Name: hourly_traffic_count, dtype: int64

# %%
df1 = df1.iloc[:9792,]
df1.tail()
# Out:
# 9787    23
# 9788    25
# 9789    16
# 9790    18
# 9791    25
# Name: hourly_traffic_count, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(df1)
plt.show()

# %%
def create_dataset(dataset, window=1):
    dataX, dataY= [], []
    for i in range(len(dataset)-window-1):
        a = dataset[i:(i+window),0]
        dataX.append(a)
        dataY.append(dataset[i+window,0])
    return np.array(dataX), np.array(dataY)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_size = int(len(df1)*0.80)
test_size = len(df1)-training_size
train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

# %%
window = 288
X_train,y_train = create_dataset(train_data,window)
X_test, y_test = create_dataset(test_data,window)

# %%
model = Sequential()
model.add(Dense(40, input_dim=window, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(1))

# %%
from tensorflow.keras import optimizers

# %%
#opt  = tensorflow.optimizers.Adagrad(learning_rate = 0.05)

tf.keras.optimizers.Adagrad(
    learning_rate=0.001, initial_accumulator_value=0.1, epsilon=1e-07,
    name='Adagrad'
)

# %%
model.compile(
    loss='mean_squared_error',
    optimizer='Adagrad')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 40)                11560
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2050
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 15,691
# Trainable params: 15,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# Out:
# Epoch 1/100
# 755/755 [==============================] - 19s 2ms/step - loss: 0.0470
# Epoch 2/100
# 755/755 [==============================] - 2s 2ms/step - loss: 0.0111
# Epoch 3/100
# 755/755 [==============================] - 2s 2ms/step - loss: 0.0101
# Epoch 4/100
# 755/755 [==============================] - 2s 2ms/step - loss: 0.0095
# Epoch 5/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0088
# Epoch 6/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0088
# Epoch 7/100
# 755/755 [==============================] - 1s 1ms/step - loss: 0.0083
# Epoch 8/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0083
# Epoch 9/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0078
# Epoch 10/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0078
# Epoch 11/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0075
# Epoch 12/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0071
# Epoch 13/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0071
# Epoch 14/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0070
# Epoch 15/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0070
# Epoch 16/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0072
# Epoch 17/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0070
# Epoch 18/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0068
# Epoch 19/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0070
# Epoch 20/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0067
# Epoch 21/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0067
# Epoch 22/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0066
# Epoch 23/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 24/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0064
# Epoch 25/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0067
# Epoch 26/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 27/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 28/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0064
# Epoch 29/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0064
# Epoch 30/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0064
# Epoch 31/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 32/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 33/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0064
# Epoch 34/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 35/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 36/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 37/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 38/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 39/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 40/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 41/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 42/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 43/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 44/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 45/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 46/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 47/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0062
# Epoch 48/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0062
# Epoch 49/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 50/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 51/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 52/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 53/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 54/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 55/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 56/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 57/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 58/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 59/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 60/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 61/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 62/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 63/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 64/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 65/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 66/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0062
# Epoch 67/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0061
# Epoch 68/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 69/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 70/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 71/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 72/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 73/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 74/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 75/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 76/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 77/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 78/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 79/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 80/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 81/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 82/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 83/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 84/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0054
# Epoch 85/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 86/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 87/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 88/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0054
# Epoch 89/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0054
# Epoch 90/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 91/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 92/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 93/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0054
# Epoch 94/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 95/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 96/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 97/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0054
# Epoch 98/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 99/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 100/100
# 755/755 [==============================] - 1s 2ms/step - loss: 0.0056

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
train_predict = train_predict.astype(int)
test_predict = test_predict.astype(int)
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
print('RMSE-train:',math.sqrt(mean_squared_error(y_train,train_predict)))
print('MAE-train:',mean_absolute_error(y_train,train_predict))
print('R_2-train:',r2_score(y_train,train_predict))
# Out:
# RMSE-train: 8.449886581781017
# MAE-train: 6.18001060445387
# R_2-train: 0.8742583028383196

# %%
print('RMSE-test:',math.sqrt(mean_squared_error(y_test,test_predict)))
print('MAE-test:',mean_absolute_error(y_test,test_predict))
print('R_2-train:',r2_score(y_test,test_predict))
# Out:
# RMSE-test: 7.36588673719259
# MAE-test: 5.6263473053892215
# R_2-train: 0.8650343848737774

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[window:len(train_predict)+window, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(window*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
